# %%
# %cd /content
# !rm -rf scPerturbEval
# !git clone https://github.com/nainika0402-creator/scPerturbEval.git
# %cd scPerturbEval
# %pip install -e .
# Out:
# /content
# Cloning into 'scPerturbEval'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 141 (delta 77), reused 107 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (141/141), 167.56 KiB | 3.10 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# /content/scPerturbEval
# Obtaining file:///content/scPerturbEval
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from scPerturbEval==0.1.0) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from scPerturbEval==0.1.0) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scPerturbEval==0.1.0) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from scPerturbEval==0.1.0) (1.6.1)
# Collecting anndata (from scPerturbEval==0.1.0)
#   Downloading anndata-0.12.16-py3-none-any.whl.metadata (9.9 kB)
# Collecting scanpy (from scPerturbEval==0.1.0)
#   Downloading scanpy-1.12.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting pertpy==1.0.6 (from scPerturbEval==0.1.0)
#   Downloading pertpy-1.0.6-py3-none-any.whl.metadata (9.6 kB)
# Collecting adjusttext (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting arviz>=1.0.0 (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading arviz-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting blitzgsea (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading blitzgsea-1.3.54.tar.gz (626 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.0/627.0 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fast-array-utils[accel,sparse] (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading fast_array_utils-1.4.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from pertpy==1.0.6->scPerturbEval==0.1.0) (3.29.0)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from pertpy==1.0.6->scPerturbEval==0.1.0) (0.11.2)
# Collecting funsor (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading funsor-0.4.7-py3-none-any.whl.metadata (8.0 kB)
# Collecting mudata (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading mudata-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting numpyro (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading numpyro-0.21.0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from pertpy==1.0.6->scPerturbEval==0.1.0) (3.1.5)
# Collecting ott-jax (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading ott_jax-0.6.0-py3-none-any.whl.metadata (21 kB)
# Collecting pubchempy (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading pubchempy-1.0.5-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from pertpy==1.0.6->scPerturbEval==0.1.0) (18.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pertpy==1.0.6->scPerturbEval==0.1.0) (2.32.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from pertpy==1.0.6->scPerturbEval==0.1.0) (13.9.4)
# Collecting scikit-misc (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading scikit_misc-0.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting sparsecca (from pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading sparsecca-0.3.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scPerturbEval==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scPerturbEval==0.1.0) (3.6.0)
# Collecting array-api-compat>=1.7.1 (from anndata->scPerturbEval==0.1.0)
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata->scPerturbEval==0.1.0) (3.16.0)
# Collecting legacy-api-wrap (from anndata->scPerturbEval==0.1.0)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata->scPerturbEval==0.1.0) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata->scPerturbEval==0.1.0) (26.1)
# Collecting scverse-misc>=0.0.3 (from anndata->scPerturbEval==0.1.0)
#   Downloading scverse_misc-0.0.7-py3-none-any.whl.metadata (4.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata->scPerturbEval==0.1.0)
#   Downloading zarr-3.2.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->scPerturbEval==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->scPerturbEval==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->scPerturbEval==0.1.0) (2026.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (2026.4.22)
# Requirement already satisfied: matplotlib>=3.9 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (3.10.0)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (3.6.1)
# Requirement already satisfied: numba>=0.60 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (0.60.0)
# Collecting pandas (from scPerturbEval==0.1.0)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: patsy in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (0.6.0)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (0.13.2)
# Collecting session-info2 (from scanpy->scPerturbEval==0.1.0)
#   Downloading session_info2-0.4.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.12 in /usr/local/lib/python3.12/dist-packages (from scanpy->scPerturbEval==0.1.0) (0.5.12)
# Collecting arviz_base<1.2.0,>=1.1.0 (from arviz>=1.0.0->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading arviz_base-1.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting arviz_stats<1.2.0,>=1.1.0 (from arviz_stats[xarray]<1.2.0,>=1.1.0->arviz>=1.0.0->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading arviz_stats-1.1.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting arviz_plots<1.2.0,>=1.1.0 (from arviz>=1.0.0->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading arviz_plots-1.1.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->scPerturbEval==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->scPerturbEval==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->scPerturbEval==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->scPerturbEval==0.1.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->scPerturbEval==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9->scanpy->scPerturbEval==0.1.0) (3.3.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60->scanpy->scPerturbEval==0.1.0) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->scPerturbEval==0.1.0) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata->scPerturbEval==0.1.0)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata->scPerturbEval==0.1.0) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata->scPerturbEval==0.1.0)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.12/dist-packages (from blitzgsea->pertpy==1.0.6->scPerturbEval==0.1.0) (1.3.0)
# Requirement already satisfied: jax>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.7.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (1.1.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.2.8)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.11.36)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.1.82)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.1.10)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->pertpy==1.0.6->scPerturbEval==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->pertpy==1.0.6->scPerturbEval==0.1.0) (2.20.0)
# Collecting makefun (from funsor->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading makefun-1.16.0-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from funsor->pertpy==1.0.6->scPerturbEval==0.1.0) (1.0.0)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from funsor->pertpy==1.0.6->scPerturbEval==0.1.0) (3.4.0)
# Requirement already satisfied: jaxlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from numpyro->pertpy==1.0.6->scPerturbEval==0.1.0) (0.7.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->pertpy==1.0.6->scPerturbEval==0.1.0) (2.0.0)
# Collecting jaxopt>=0.8 (from ott-jax->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading jaxopt-0.8.5-py3-none-any.whl.metadata (3.3 kB)
# Collecting lineax>=0.0.7 (from ott-jax->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading lineax-0.1.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pertpy==1.0.6->scPerturbEval==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pertpy==1.0.6->scPerturbEval==0.1.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pertpy==1.0.6->scPerturbEval==0.1.0) (2.5.0)
# Requirement already satisfied: pyomo in /usr/local/lib/python3.12/dist-packages (from sparsecca->pertpy==1.0.6->scPerturbEval==0.1.0) (6.10.0)
# Requirement already satisfied: xarray>=2024.11.0 in /usr/local/lib/python3.12/dist-packages (from arviz_base<1.2.0,>=1.1.0->arviz>=1.0.0->pertpy==1.0.6->scPerturbEval==0.1.0) (2025.12.0)
# Requirement already satisfied: lazy_loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from arviz_base<1.2.0,>=1.1.0->arviz>=1.0.0->pertpy==1.0.6->scPerturbEval==0.1.0) (0.5)
# Requirement already satisfied: xarray-einstats in /usr/local/lib/python3.12/dist-packages (from arviz_stats[xarray]<1.2.0,>=1.1.0->arviz>=1.0.0->pertpy==1.0.6->scPerturbEval==0.1.0) (0.10.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.0->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.5.4)
# Collecting equinox>=0.11.10 (from lineax>=0.0.7->ott-jax->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading equinox-0.13.8-py3-none-any.whl.metadata (18 kB)
# Collecting jax>=0.6.0 (from flax->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading jax-0.10.0-py3-none-any.whl.metadata (13 kB)
# Collecting jaxtyping>=0.2.24 (from lineax>=0.0.7->ott-jax->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading jaxtyping-0.3.9-py3-none-any.whl.metadata (7.4 kB)
# Collecting jaxlib>=0.7.0 (from numpyro->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading jaxlib-0.10.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->pertpy==1.0.6->scPerturbEval==0.1.0) (0.1.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (1.4.0)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (1.14.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (5.29.6)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (4.15.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (4.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (5.9.5)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (0.22.1)
# Collecting wadler-lindig>=0.1.0 (from equinox>=0.11.10->lineax>=0.0.7->ott-jax->pertpy==1.0.6->scPerturbEval==0.1.0)
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (2025.3.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->pertpy==1.0.6->scPerturbEval==0.1.0) (3.23.1)
# Downloading pertpy-1.0.6-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.7/225.7 kB 22.5 MB/s eta 0:00:00
# Downloading anndata-0.12.16-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 19.0 MB/s eta 0:00:00
# Downloading scanpy-1.12.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.6 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 92.6 MB/s eta 0:00:00
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.6 MB/s eta 0:00:00
# Downloading arviz-1.1.0-py3-none-any.whl (9.2 kB)
# Downloading fast_array_utils-1.4.1-py3-none-any.whl (39 kB)
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading scverse_misc-0.0.7-py3-none-any.whl (13 kB)
# Downloading zarr-3.2.1-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 33.4 MB/s eta 0:00:00
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Downloading funsor-0.4.7-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.2/175.2 kB 15.8 MB/s eta 0:00:00
# Downloading mudata-0.3.8-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.7 MB/s eta 0:00:00
# Downloading numpyro-0.21.0-py3-none-any.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.8/394.8 kB 38.1 MB/s eta 0:00:00
# Downloading ott_jax-0.6.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 22.5 MB/s eta 0:00:00
# Downloading pubchempy-1.0.5-py3-none-any.whl (21 kB)
# Downloading scikit_misc-0.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 21.3 MB/s eta 0:00:00
# Downloading session_info2-0.4.1-py3-none-any.whl (17 kB)
# Downloading sparsecca-0.3.1-py3-none-any.whl (12 kB)
# Downloading arviz_base-1.1.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.2 MB/s eta 0:00:00
# Downloading arviz_plots-1.1.0-py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.8/237.8 kB 21.3 MB/s eta 0:00:00
# Downloading arviz_stats-1.1.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.9/179.9 kB 19.7 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading jaxopt-0.8.5-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.4/172.4 kB 18.9 MB/s eta 0:00:00
# Downloading lineax-0.1.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 8.8 MB/s eta 0:00:00
# Downloading jax-0.10.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 123.1 MB/s eta 0:00:00
# Downloading jaxlib-0.10.0-cp312-cp312-manylinux_2_27_x86_64.whl (85.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 MB 30.3 MB/s eta 0:00:00
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 142.5 MB/s eta 0:00:00
# Downloading makefun-1.16.0-py2.py3-none-any.whl (22 kB)
# Downloading equinox-0.13.8-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 20.4 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.9-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.3 MB/s eta 0:00:00
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Building wheels for collected packages: scPerturbEval, blitzgsea
#   Building editable for scPerturbEval (pyproject.toml) ... done
#   Created wheel for scPerturbEval: filename=scperturbeval-0.1.0-0.editable-py3-none-any.whl size=1869 sha256=b47acf6996fd8f33b3c909136f8b689f80f711f34926afb009bcb7bd059a8d8a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lkqbssdi/wheels/13/fd/cc/ff8681793a88e7664941daa019e167be8a63abcc484d321f8f
#   Building wheel for blitzgsea (setup.py) ... done
#   Created wheel for blitzgsea: filename=blitzgsea-1.3.54-py3-none-any.whl size=625671 sha256=38922b7e9e5436383b0797107104183e69c68b8958a753b377c8a8e3dbbeca1c
#   Stored in directory: /root/.cache/pip/wheels/e3/00/84/15131449d6f397371baa95614491906dbd4ca2a932194b9494
# Successfully built scPerturbEval blitzgsea
# Installing collected packages: makefun, wadler-lindig, session-info2, scikit-misc, pubchempy, numcodecs, legacy-api-wrap, funsor, fast-array-utils, donfig, array-api-compat, zarr, scverse-misc, pandas, jaxtyping, jaxlib, arviz_stats, jax, anndata, adjusttext, sparsecca, numpyro, mudata, jaxopt, equinox, blitzgsea, arviz_base, scanpy, lineax, ott-jax, arviz_plots, arviz, pertpy, scPerturbEval
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
#   Attempting uninstall: arviz
#     Found existing installation: arviz 0.22.0
#     Uninstalling arviz-0.22.0:
#       Successfully uninstalled arviz-0.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# pymc 5.28.4 requires arviz<1.0,>=0.13.0, but you have arviz 1.1.0 which is incompatible.
# Successfully installed adjusttext-1.3.0 anndata-0.12.16 array-api-compat-1.14.0 arviz-1.1.0 arviz_base-1.1.0 arviz_plots-1.1.0 arviz_stats-1.1.0 blitzgsea-1.3.54 donfig-0.8.1.post1 equinox-0.13.8 fast-array-utils-1.4.1 funsor-0.4.7 jax-0.10.0 jaxlib-0.10.0 jaxopt-0.8.5 jaxtyping-0.3.9 legacy-api-wrap-1.5 lineax-0.1.1 makefun-1.16.0 mudata-0.3.8 numcodecs-0.16.5 numpyro-0.21.0 ott-jax-0.6.0 pandas-2.3.3 pertpy-1.0.6 pubchempy-1.0.5 scPerturbEval-0.1.0 scanpy-1.12.1 scikit-misc-0.5.2 scverse-misc-0.0.7 session-info2-0.4.1 sparsecca-0.3.1 wadler-lindig-0.1.7 zarr-3.2.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/scPerturbEval_data.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("project")

os.listdir("project")
# Out:
# ['__MACOSX', 'scPerturbEval_data']

# %%
# !find /content -name "norman.h5ad"

# %% [markdown]
# # Fold 0: Metrics for Norman under Additive split

# %%
# fold 0
# !python -m scPerturbEval.evaluations \
  --real "/content/scPerturbEval/project/scPerturbEval_data/fold0_norman_additive_real.h5ad" \
  --pred "/content/scPerturbEval/project/scPerturbEval_data/fold0_norman_additive_pred.h5ad" \
  --condition-column perturbation \
  --control-label control \
  --space raw \
  --metrics root_mean_squared_error pearson_distance wmse pcc_delta pearson_delta_pert weighted_r2_delta pds_cosine matrix_distance top_deg_recall deg_direction_agreement deg_spearman_lfc \
  --top-k-deg 50 \
  --pathway-gene-sets MSigDB_Hallmark_2020 \
  --pathway-top-k 10 \
  --pathway-reference perturbed_centroid \
  --out /content/scdfm_fold0_metrics_raw.csv
# Out:
# <frozen runpy>:128: RuntimeWarning: 'scPerturbEval.evaluations' found in sys.modules after import of package 'scPerturbEval', but prior to execution of 'scPerturbEval.evaluations'; this may result in unpredictable behaviour
# Wrote 1 rows to /content/scdfm_fold0_metrics_raw.csv
# space  n_conditions  deg_fallback_used  root_mean_squared_error  pearson_distance    wmse  pcc_delta  pearson_delta_pert  weighted_r2_delta  pds_cosine  matrix_distance  matrix_distance_raw  top_deg_recall  deg_direction_agreement  deg_spearman_lfc
#   raw            38              False                 0.051412          0.004969 0.01459   0.872395            0.836109           0.865468    0.984234         0.167155             6.184746        0.304074                 0.989211         -0.096982

# %%
# PCA pass (distribution-only)
# !python -m scPerturbEval.evaluations \
  --real "/content/scPerturbEval/project/scPerturbEval_data/fold0_norman_additive_real.h5ad" \
  --pred "/content/scPerturbEval/project/scPerturbEval_data/fold0_norman_additive_pred.h5ad" \
  --condition-column perturbation \
  --space pca \
  --n-components 20 \
  --metrics wasserstein mmd \
  --out /content/scdfm_fold0_metrics_pca.csv
# Out:
# <frozen runpy>:128: RuntimeWarning: 'scPerturbEval.evaluations' found in sys.modules after import of package 'scPerturbEval', but prior to execution of 'scPerturbEval.evaluations'; this may result in unpredictable behaviour
# Wrote 1 rows to /content/scdfm_fold0_metrics_pca.csv
# space  n_conditions  deg_fallback_used  wasserstein      mmd
#   pca            38              False     0.382037 0.052093

# %% [markdown]
# # Fold 1: Metrics for Norman under Additive split

# %%
# fold 1
# !python -m scPerturbEval.evaluations \
  --real "/content/scPerturbEval/project/scPerturbEval_data/fold1_norman_additive_real.h5ad" \
  --pred "/content/scPerturbEval/project/scPerturbEval_data/fold1_norman_additive_pred.h5ad" \
  --condition-column perturbation \
  --control-label control \
  --space raw \
  --metrics root_mean_squared_error pearson_distance wmse pcc_delta pearson_delta_pert weighted_r2_delta pds_cosine matrix_distance top_deg_recall deg_direction_agreement deg_spearman_lfc \
  --top-k-deg 50 \
  --pathway-gene-sets MSigDB_Hallmark_2020 \
  --pathway-top-k 10 \
  --pathway-reference perturbed_centroid \
  --out /content/scdfm_fold1_metrics_raw.csv
# Out:
# <frozen runpy>:128: RuntimeWarning: 'scPerturbEval.evaluations' found in sys.modules after import of package 'scPerturbEval', but prior to execution of 'scPerturbEval.evaluations'; this may result in unpredictable behaviour
# Wrote 1 rows to /content/scdfm_fold1_metrics_raw.csv
# space  n_conditions  deg_fallback_used  root_mean_squared_error  pearson_distance     wmse  pcc_delta  pearson_delta_pert  weighted_r2_delta  pds_cosine  matrix_distance  matrix_distance_raw  top_deg_recall  deg_direction_agreement  deg_spearman_lfc
#   raw            38              False                 0.050875          0.005013 0.014709   0.874933            0.853246           0.880478    0.981231         0.157547             5.829257         0.36284                 0.990442         -0.011958

# %%
# PCA pass (distribution-only)
# !python -m scPerturbEval.evaluations \
  --real "/content/scPerturbEval/project/scPerturbEval_data/fold1_norman_additive_real.h5ad" \
  --pred "/content/scPerturbEval/project/scPerturbEval_data/fold1_norman_additive_pred.h5ad" \
  --condition-column perturbation \
  --space pca \
  --n-components 20 \
  --metrics wasserstein mmd \
  --out /content/scdfm_fold1_metrics_pca.csv
# Out:
# <frozen runpy>:128: RuntimeWarning: 'scPerturbEval.evaluations' found in sys.modules after import of package 'scPerturbEval', but prior to execution of 'scPerturbEval.evaluations'; this may result in unpredictable behaviour
# Wrote 1 rows to /content/scdfm_fold1_metrics_pca.csv
# space  n_conditions  deg_fallback_used  wasserstein     mmd
#   pca            38              False     0.381477 0.04931

# %% [markdown]
# # Aggregating Metrics across 2 folds :

# %%
# !python scripts/aggregate_fold_metrics.py \
  --csv-paths /content/scdfm_fold0_metrics_raw.csv /content/scdfm_fold1_metrics_raw.csv \
  --out-per-fold /content/scdfm_metrics_raw_per_fold.csv \
  --out-summary /content/scdfm_metrics_raw_summary.csv
# Out:
# Wrote per-fold means: /content/scdfm_metrics_raw_per_fold.csv
# Wrote summary mean/std: /content/scdfm_metrics_raw_summary.csv
#                  metric      mean      std  n_folds
#       deg_fallback_used  0.000000 0.000000        2
# root_mean_squared_error  0.051144 0.000380        2
#        pearson_distance  0.004991 0.000032        2
#                    wmse  0.014650 0.000084        2
#               pcc_delta  0.873664 0.001795        2
#      pearson_delta_pert  0.844677 0.012118        2
#       weighted_r2_delta  0.872973 0.010614        2
#              pds_cosine  0.982733 0.002123        2
#         matrix_distance  0.162351 0.006794        2
#     matrix_distance_raw  6.007002 0.251369        2
#          top_deg_recall  0.333457 0.041554        2
# deg_direction_agreement  0.989826 0.000870        2
#        deg_spearman_lfc -0.054470 0.060121        2

# %%
# !python scripts/aggregate_fold_metrics.py \
  --csv-paths /content/scdfm_fold0_metrics_pca.csv /content/scdfm_fold1_metrics_pca.csv \
  --out-per-fold /content/scdfm_metrics_pca_per_fold.csv \
  --out-summary /content/scdfm_metrics_pca_summary.csv
# Out:
# Wrote per-fold means: /content/scdfm_metrics_pca_per_fold.csv
# Wrote summary mean/std: /content/scdfm_metrics_pca_summary.csv
#            metric     mean      std  n_folds
# deg_fallback_used 0.000000 0.000000        2
#       wasserstein 0.381757 0.000396        2
#               mmd 0.050701 0.001968        2
